# %%
#Jeremy Brouillet

# %% [markdown]
# Introduction
# Image segmentation, namely identifying different classes in an image, is an important problem in computer vision. Be it identifying cancerous and non-cancerous cells or distinguishing between pedestrians, cars, and roads, there are a myriad set of applications. One can turn images into actionable decisions, such as performing surgery or steering a car into an open lane. The goal of this notebook is to demonstrate image segmentation on standard dataset.
#
# To solve this task, one can apply deep learning. By applying a neural net to the pixel-level information, I can encode the features that are significant for identifying objects. A decoder is fed these features along with the image data and is able to reconstruct the image with classes rather than RGB pixel values.
#
# There has been a significant amount of work into this active application and area of research. A number of architectures have been used, such as U-Net [1], Segnet[2], and Fully Convolutional Networks (FCN) [3]. These networks use multiple layers of convolution, ReLu, and pooling layers to encode the images, reducing the width and height while increasing the number of feature channels. These are then upsampled and combined with passthrough networks. I will be using a modified U-Net structure.
#
# Data Set:
# There are a number of datasets associated with image segmentation. I will be using the Cityscapes [4] dataset. Cityscapes is a number of well-annotated photos taken in a variety of European cities.
#
# Model:
# I use VGGnet [5] trained on ImageNet [6] to build our initial encoder. The network consists of a series of convolution and pooling layers. By using an established model trained on a large dataset, O will have more rapid convergence, as VGGnet will have already identified the proper set of features relevant to classification and will feed them to the decoder network.
#
# For the decoder network, I use a modified U-Net architecture. It consists of a series of convolutions, upsampling, batch renormalization layers, and passthrough layers. Upsampling layers are needed to increase the pixel count back to the original resolution of the image. Batch renormalization ensures that the gradients through the network do not vanish. By using passthrough from the encoder VGGnet, we can use more of the original positional information. By using successive layers, we can decoder and reconstruct the image with proper class labels.
#
# Overview:
# I load the libraries and data, examine basic images, load the pre-trained encoder layer, build the decoder layer on top of it, train the full neural network, and discuss the results. Lastly, I provide addition steps for future work.
#
# 1. Ronneberger, O., Fischer, P., Brox, T.: U-Net: Convolutional Networks for Biomedical Image Segmentation (2015), arXiv:1505.04597 [cs.CV]
# 2. Badrinarayanan, V., Kendall, A., Cipolla, R.: SegNet: A Deep Convolutional Encoder-Decoder Architecture for Image Segmentation (2016), arXiv:1511.00561 [cs.CV]
# 3. Shelhamer, E., Long, J., Darrell, T.: Fully Convolutional Networks for Semantic Segmentation (2016), arXiv:1605.06211 [cs.CV]
# 4. M. Cordts, M. Omran, S. Ramos, T. Rehfeld, M. Enzweiler, R. Benenson, U. Franke, S. Roth, and B. Schiele, “The Cityscapes Dataset for Semantic Urban Scene Understanding,” in Proc. of the IEEE Conference on Computer Vision and Pattern Recognition (CVPR), 2016.
# 5. Simonyan, K., Zisserman, A.: Very Deep Convolutional Networks for Large-Scale Image Recognition (2015), arXiv:1409.1556 [cs.CV]
# 6. Russakovsky O.*, Deng J.*, Su H., Krause J, Satheesh S., Ma S.,  Huang Z., Karpathy A., Khosla A., Bernstein M., Berg A. C., Fei-Fei L. "ImageNet Large Scale Visual Recognition Challenge," in IJCV, 2015.

# %%
#Load tensforflow, the deep learning framework I will be using. Tensorflow v2.x.
import tensorflow as tf
#Limits the memory consumption of the GPU
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True) 
# %load_ext tensorboard

# %%
#Import other useful libraries libraries
import numpy as np
import matplotlib.pyplot as plt
import os
import imageio
from skimage.transform import rescale, resize
import cv2
from tensorflow import keras
from tensorflow.keras.layers import Convolution2D,BatchNormalization,ReLU,LeakyReLU,Add,Activation
from tensorflow.keras.layers import GlobalAveragePooling2D,AveragePooling2D,UpSampling2D
import gc
import datetime

# %%
#Load in image dataset
#Note that the license agreement for Cityscapes instructs me to not to post the data publically.
#If you are interested, you can download the dataset at https://www.cityscapes-dataset.com/downloads/.
def get_images_x(pathX,reduced_image_count):
    names=os.listdir(pathX)
    names.sort()
    names_r = names[0:reduced_image_count]
    img_g=[]
    for name in names:
        img=imageio.imread(pathX+name)
        img_g.append(img)
    return np.array(img_g)

def get_images_y(pathY,reduced_image_count):
    names=os.listdir(pathY)
    names.sort()
    names_r = names[0:reduced_image_count*4] 
    img_g=[]
    for name in names:
        if name[-12:]=='labelIds.png': #Choose the proper type of train_y image.
            img=imageio.imread(pathY+name)
            img_g.append(img)
    return np.array(img_g)

#strasbourg: 365 images. 
#Owing to limited compute power, we train on a reduced subset of images.
pathX='./input/leftImg8bit/train/strasbourg/'
pathY='./input/gtFine/train/strasbourg/'
reduced_image_count = 32 #Further restrict the data set
train_x = get_images_x(pathX,reduced_image_count)
train_y = get_images_y(pathY,reduced_image_count)

#ulm: 95 images
pathXtest='./input/leftImg8bit/train/ulm/'
pathYtest='./input/gtFine/train/ulm/'
reduced_image_count = 32 #Further restrict the data set
test_x = get_images_x(pathXtest,reduced_image_count)
test_y = get_images_y(pathYtest,reduced_image_count)

#Resize Image. Note that this stretches the image as the aspect ratio changes.
#Image needs to be resized to match the pre-training of VGGnet on ImageNet
IMG_WIDTH=224
IMG_HEIGHT=224
train_x_resized = tf.image.resize(train_x, [IMG_WIDTH, IMG_HEIGHT], method='nearest')
train_y_resized = tf.image.resize(np.reshape(train_y,(*np.shape(train_y),1)), [IMG_WIDTH, IMG_HEIGHT], method='nearest')
test_x_resized = tf.image.resize(test_x, [IMG_WIDTH, IMG_HEIGHT], method='nearest')
test_y_resized = tf.image.resize(np.reshape(test_y,(*np.shape(test_y),1)), [IMG_WIDTH, IMG_HEIGHT], method='nearest')

# %%
#Typical images from the dataset: 
plt.imshow(train_x[2], interpolation='nearest')

# %%
#Labeling of the image: 
plt.imshow(train_y[2], interpolation='nearest')

# %%
#Test images: Similar to training set
plt.imshow(test_x[2], interpolation='nearest')

# %%
#Test image, class label truth.
#A more sophisticated approach would be to use a validation training set
#It would give a train/validation/test split
plt.imshow(test_y[2], interpolation='nearest')

# %%
listUniques = np.unique(np.array(train_y_resized))
print("Number of classes: " + str(len(listUniques)))
# Out:
# Number of classes: 33

# %%
#CPU is used train as the model does not easily fit into my 2GB GPU memory.
with tf.device('/CPU:0'): 
    model_vgg = tf.keras.applications.VGG16(weights='imagenet',include_top=False)
    model_vgg.trainable = False
model_vgg.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, None, None, 3)]   0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, None, None, 64)    1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, None, None, 64)    36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, None, None, 64)    0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, None, None, 128)   73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, None, None, 128)   147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, None, None, 128)   0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, None, None, 256)   295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, None, None, 256)   0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, None, None, 512)   1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, None, None, 512)   0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, None, None, 512)   0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# tf.summary() shows our model. However, the output shapes not as informative as they could be. The first column, None, refers to the number of rows we have in our training set. The second and third None correspond to rows and columns, which is compressed by the various pooling layers. As I need to use passthrough layers in order to bring information forward to higher levels in the network, it is necessary to know the actual shape when used on the 224x224 training set. Hence, the use of a helper function below to identify the layer shapes.

# %%
def findLayerShape(model,layer_name):
    index = None
    model_name = model_other
    for idx, layer in enumerate(model_name.layers):
        if layer.name == (layer_name):
            index = idx
            print(index)
           # break
    model_moving = tf.keras.models.Model(model_name.input,model_name.layers[index].output)
    #model_name.summary()
    return np.shape(model_moving.predict(train_x_resized[0:5]))
ln = []
for idx,layer in enumerate(model_other.layers):
    layer_name = model_other.layers[idx].name
    layerShape = findLayerShape(model_other,layer_name)
    ln.append((layer_name,layerShape))

# %%
for layerName,layerShape in ln:
    print(layerName +" : " + str(layerShape))
# Out:
# input_1 : (5, 224, 224, 3)
# block1_conv1 : (5, 224, 224, 64)
# block1_conv2 : (5, 224, 224, 64)
# block1_pool : (5, 112, 112, 64)
# block2_conv1 : (5, 112, 112, 128)
# block2_conv2 : (5, 112, 112, 128)
# block2_pool : (5, 56, 56, 128)
# block3_conv1 : (5, 56, 56, 256)
# block3_conv2 : (5, 56, 56, 256)
# block3_conv3 : (5, 56, 56, 256)
# block3_pool : (5, 28, 28, 256)
# block4_conv1 : (5, 28, 28, 512)
# block4_conv2 : (5, 28, 28, 512)
# block4_conv3 : (5, 28, 28, 512)
# block4_pool : (5, 14, 14, 512)
# block5_conv1 : (5, 14, 14, 512)
# block5_conv2 : (5, 14, 14, 512)
# block5_conv3 : (5, 14, 14, 512)
# block5_pool : (5, 7, 7, 512)
# conv2d : (5, 7, 7, 256)
# up_sampling2d : (5, 14, 14, 256)
# batch_normalization : (5, 14, 14, 256)
# conv2d_1 : (5, 14, 14, 128)
# up_sampling2d_1 : (5, 28, 28, 128)
# batch_normalization_1 : (5, 28, 28, 128)
# conv2d_2 : (5, 28, 28, 64)
# up_sampling2d_2 : (5, 56, 56, 64)
# batch_normalization_2 : (5, 56, 56, 64)
# conv2d_3 : (5, 56, 56, 32)
# up_sampling2d_3 : (5, 112, 112, 32)
# batch_normalization_3 : (5, 112, 112, 32)
# conv2d_4 : (5, 112, 112, 2)
# up_sampling2d_4 : (5, 224, 224, 2)
# batch_normalization_4 : (5, 224, 224, 2)
# conv2d_5 : (5, 224, 224, 34)

# %% [markdown]
# I choose SparseCategoricalCrossentropy loss as we have a large number of classes. In order for this to work properly, the final layer is a softmax layer with a number of filters of 34, corresponding to the number of classes. This layer will give the probibility that each pixel corresponds to each class, with a vector of length 34 that sums to 1.

# %%
#Build the full neural net
with tf.device('/CPU:0'):
    conv6 = tf.keras.layers.Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(model_vgg.output)
    up6 = tf.keras.layers.UpSampling2D(size = (2,2))(conv6)
    batch1 = tf.keras.layers.BatchNormalization()(up6)
    merge1 = tf.keras.layers.concatenate([model_vgg.get_layer('block4_pool').output,batch1], axis = 3)
    conv7 = tf.keras.layers.Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge1)
    up7 = tf.keras.layers.UpSampling2D(size = (2,2))(conv7)
    batch2 = tf.keras.layers.BatchNormalization()(up7)
    merge2 = tf.keras.layers.concatenate([model_vgg.get_layer('block3_pool').output,batch2], axis = 3)
    conv8 = tf.keras.layers.Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge2)
    up8 = tf.keras.layers.UpSampling2D(size = (2,2))(conv8)
    batch3 = tf.keras.layers.BatchNormalization()(up8)
    merge3 = tf.keras.layers.concatenate([model_vgg.get_layer('block2_pool').output,batch3], axis = 3)
    conv9 = tf.keras.layers.Conv2D(56, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge3)
    up9 = tf.keras.layers.UpSampling2D(size = (2,2))(conv9)
    batch4 = tf.keras.layers.BatchNormalization()(up9)
    merge4 = tf.keras.layers.concatenate([model_vgg.get_layer('block1_pool').output,batch4], axis = 3)
    conv10 = tf.keras.layers.Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge4)
    up10 = tf.keras.layers.UpSampling2D(size = (2,2))(conv10)
    batch5 = tf.keras.layers.BatchNormalization()(up10)
    conv11 = tf.keras.layers.Conv2D(34, 1, activation = 'softmax')(batch5)
    model_other = tf.keras.models.Model(model_vgg.input,conv11)
    model_other.compile(optimizer=tf.keras.optimizers.Adam(0.0001),loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                  metrics=['accuracy'])

# %%
#Summary of the full model
model_other.summary()
# Out:
# Model: "model_241"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, None, None, 6 1792        input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, None, None, 6 36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, None, None, 6 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, None, None, 1 73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, None, None, 1 147584      block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, None, None, 1 0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, None, None, 2 295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, None, None, 2 590080      block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, None, None, 2 590080      block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, None, None, 2 0           block3_conv3[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, None, None, 5 1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, None, None, 5 2359808     block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, None, None, 5 2359808     block4_conv2[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, None, None, 5 0           block4_conv3[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv2D)           (None, None, None, 5 2359808     block4_pool[0][0]
# __________________________________________________________________________________________________
# block5_conv2 (Conv2D)           (None, None, None, 5 2359808     block5_conv1[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv2D)           (None, None, None, 5 2359808     block5_conv2[0][0]
# __________________________________________________________________________________________________
# block5_pool (MaxPooling2D)      (None, None, None, 5 0           block5_conv3[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, None, None, 5 2359808     block5_pool[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_45 (UpSampling2D) (None, None, None, 5 0           conv2d_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, None, None, 5 2048        up_sampling2d_45[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, None, None, 1 0           block4_pool[0][0]
#                                                                  batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, None, None, 2 2359552     concatenate_20[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_46 (UpSampling2D) (None, None, None, 2 0           conv2d_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, None, None, 2 1024        up_sampling2d_46[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, None, None, 5 0           block3_pool[0][0]
#                                                                  batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, None, None, 1 589952      concatenate_21[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_47 (UpSampling2D) (None, None, None, 1 0           conv2d_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, None, None, 1 512         up_sampling2d_47[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, None, None, 2 0           block2_pool[0][0]
#                                                                  batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, None, None, 5 129080      concatenate_22[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_48 (UpSampling2D) (None, None, None, 5 0           conv2d_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, None, None, 5 224         up_sampling2d_48[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, None, None, 1 0           block1_pool[0][0]
#                                                                  batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, None, None, 2 2162        concatenate_23[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_49 (UpSampling2D) (None, None, None, 2 0           conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, None, None, 2 8           up_sampling2d_49[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, None, None, 3 102         batch_normalization_49[0][0]
# ==================================================================================================
# Total params: 20,159,160
# Trainable params: 20,157,252
# Non-trainable params: 1,908
# __________________________________________________________________________________________________

# %% [markdown]
# Begin training. Training was run over a number of training periods. With successive training steps, the loss decreases and the accuracy increases.

# %%
with tf.device('/CPU:0'):
    #Enable tensorboard
    log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
    tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
    #Begin training
    history = model_other.fit(train_x_resized[0:5],train_y_resized[0:5],epochs=50,callbacks=[tensorboard_callback])
# Out:
# Epoch 1/50
# WARNING:tensorflow:7 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7f94f2d17a60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please  define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 1s/step - loss: 3.5244 - accuracy: 0.0295
# Epoch 2/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5242 - accuracy: 0.0318
# Epoch 3/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5239 - accuracy: 0.0335
# Epoch 4/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5237 - accuracy: 0.0356
# Epoch 5/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5234 - accuracy: 0.0366
# Epoch 6/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5232 - accuracy: 0.0381
# Epoch 7/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5229 - accuracy: 0.0404
# Epoch 8/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5227 - accuracy: 0.0459
# Epoch 9/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5224 - accuracy: 0.0735
# Epoch 10/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5221 - accuracy: 0.0790
# Epoch 11/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5219 - accuracy: 0.0814
# Epoch 12/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5218 - accuracy: 0.0824
# Epoch 13/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5217 - accuracy: 0.0833
# Epoch 14/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5217 - accuracy: 0.0836
# Epoch 15/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5216 - accuracy: 0.0838
# Epoch 16/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5215 - accuracy: 0.0841
# Epoch 17/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5214 - accuracy: 0.0843
# Epoch 18/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5213 - accuracy: 0.0846
# Epoch 19/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5212 - accuracy: 0.0848
# Epoch 20/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5211 - accuracy: 0.0849
# Epoch 21/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5211 - accuracy: 0.0853
# Epoch 22/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5210 - accuracy: 0.0856
# Epoch 23/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5209 - accuracy: 0.0861
# Epoch 24/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5208 - accuracy: 0.0863
# Epoch 25/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5207 - accuracy: 0.0862
# Epoch 26/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5206 - accuracy: 0.0864
# Epoch 27/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5205 - accuracy: 0.0862
# Epoch 28/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5204 - accuracy: 0.0864
# Epoch 29/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5203 - accuracy: 0.0876
# Epoch 30/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5203 - accuracy: 0.0873
# Epoch 31/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5202 - accuracy: 0.0873
# Epoch 32/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5201 - accuracy: 0.0871
# Epoch 33/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5201 - accuracy: 0.0869
# Epoch 34/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5200 - accuracy: 0.0866
# Epoch 35/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5199 - accuracy: 0.0864
# Epoch 36/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5199 - accuracy: 0.0863
# Epoch 37/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5198 - accuracy: 0.0864
# Epoch 38/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5198 - accuracy: 0.0870
# Epoch 39/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5197 - accuracy: 0.0873
# Epoch 40/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5196 - accuracy: 0.0876
# Epoch 41/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5196 - accuracy: 0.0880
# Epoch 42/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5195 - accuracy: 0.0886
# Epoch 43/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5194 - accuracy: 0.0891
# Epoch 44/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5194 - accuracy: 0.0896
# Epoch 45/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5193 - accuracy: 0.0901
# Epoch 46/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5192 - accuracy: 0.0905
# Epoch 47/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5192 - accuracy: 0.0909
# Epoch 48/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5191 - accuracy: 0.0911
# Epoch 49/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5191 - accuracy: 0.0913
# Epoch 50/50
# 1/1 [==============================] - 1s 1s/step - loss: 3.5190 - accuracy: 0.0915

# %%
with tf.device('/CPU:0'):
    history4 = model_other.fit(train_x_resized,train_y_resized,epochs=50
                               ,callbacks=[tensorboard_callback])
# Out:
# Epoch 1/50
# 12/12 [==============================] - 212s 18s/step - loss: 3.4931 - accuracy: 0.1283
# Epoch 2/50
# 12/12 [==============================] - 203s 17s/step - loss: 3.4922 - accuracy: 0.1473
# Epoch 3/50
# 12/12 [==============================] - 203s 17s/step - loss: 3.4915 - accuracy: 0.1819
# Epoch 4/50
# 12/12 [==============================] - 203s 17s/step - loss: 3.4909 - accuracy: 0.1935
# Epoch 5/50
# 12/12 [==============================] - 201s 17s/step - loss: 3.4903 - accuracy: 0.2098
# Epoch 6/50
# 12/12 [==============================] - 202s 17s/step - loss: 3.4901 - accuracy: 0.2234
# Epoch 7/50
# 12/12 [==============================] - 202s 17s/step - loss: 3.4893 - accuracy: 0.2249
# Epoch 8/50
# 12/12 [==============================] - 201s 17s/step - loss: 3.4894 - accuracy: 0.2294
# Epoch 9/50
# 12/12 [==============================] - 201s 17s/step - loss: 3.4889 - accuracy: 0.2375
# Epoch 10/50
# 12/12 [==============================] - 201s 17s/step - loss: 3.4884 - accuracy: 0.2376
# Epoch 11/50
# 12/12 [==============================] - 203s 17s/step - loss: 3.4877 - accuracy: 0.2484
# Epoch 12/50
# 12/12 [==============================] - 202s 17s/step - loss: 3.4872 - accuracy: 0.2546
# Epoch 13/50
# 12/12 [==============================] - 201s 17s/step - loss: 3.4864 - accuracy: 0.2685
# Epoch 14/50
# 12/12 [==============================] - 201s 17s/step - loss: 3.4860 - accuracy: 0.2711
# Epoch 15/50
# 12/12 [==============================] - 203s 17s/step - loss: 3.4854 - accuracy: 0.2780
# Epoch 16/50
# 12/12 [==============================] - 202s 17s/step - loss: 3.4845 - accuracy: 0.2803
# Epoch 17/50
# 12/12 [==============================] - 201s 17s/step - loss: 3.4835 - accuracy: 0.2899
# Epoch 18/50
# 12/12 [==============================] - 200s 17s/step - loss: 3.4827 - accuracy: 0.2928
# Epoch 19/50
# 12/12 [==============================] - 202s 17s/step - loss: 3.4821 - accuracy: 0.2946
# Epoch 20/50
# 12/12 [==============================] - 202s 17s/step - loss: 3.4813 - accuracy: 0.2976
# Epoch 21/50
# 12/12 [==============================] - 201s 17s/step - loss: 3.4805 - accuracy: 0.2985
# Epoch 22/50
# 12/12 [==============================] - 203s 17s/step - loss: 3.4796 - accuracy: 0.3042
# Epoch 23/50
# 12/12 [==============================] - 201s 17s/step - loss: 3.4791 - accuracy: 0.3020
# Epoch 24/50
# 12/12 [==============================] - 202s 17s/step - loss: 3.4778 - accuracy: 0.3072
# Epoch 25/50
# 12/12 [==============================] - 201s 17s/step - loss: 3.4772 - accuracy: 0.3094
# Epoch 26/50
# 12/12 [==============================] - 202s 17s/step - loss: 3.4765 - accuracy: 0.3105
# Epoch 27/50
# 12/12 [==============================] - 204s 17s/step - loss: 3.4756 - accuracy: 0.3097
# Epoch 28/50
# 12/12 [==============================] - 202s 17s/step - loss: 3.4747 - accuracy: 0.3123
# Epoch 29/50
# 12/12 [==============================] - 203s 17s/step - loss: 3.4744 - accuracy: 0.3143
# Epoch 30/50
# 12/12 [==============================] - 203s 17s/step - loss: 3.4731 - accuracy: 0.3144
# Epoch 31/50
# 12/12 [==============================] - 201s 17s/step - loss: 3.4721 - accuracy: 0.3194
# Epoch 32/50
# 12/12 [==============================] - 203s 17s/step - loss: 3.4717 - accuracy: 0.3193
# Epoch 33/50
# 12/12 [==============================] - 202s 17s/step - loss: 3.4710 - accuracy: 0.3185
# Epoch 34/50
# 12/12 [==============================] - 202s 17s/step - loss: 3.4702 - accuracy: 0.3220
# Epoch 35/50
# 12/12 [==============================] - 203s 17s/step - loss: 3.4694 - accuracy: 0.3215
# Epoch 36/50
# 12/12 [==============================] - 201s 17s/step - loss: 3.4685 - accuracy: 0.3234
# Epoch 37/50
# 12/12 [==============================] - 203s 17s/step - loss: 3.4678 - accuracy: 0.3238
# Epoch 38/50
# 12/12 [==============================] - 203s 17s/step - loss: 3.4670 - accuracy: 0.3255
# Epoch 39/50
# 12/12 [==============================] - 203s 17s/step - loss: 3.4663 - accuracy: 0.3278
# Epoch 40/50
# 12/12 [==============================] - 202s 17s/step - loss: 3.4655 - accuracy: 0.3268
# Epoch 41/50
# 12/12 [==============================] - 201s 17s/step - loss: 3.4648 - accuracy: 0.3310
# Epoch 42/50
# 12/12 [==============================] - 201s 17s/step - loss: 3.4642 - accuracy: 0.3296
# Epoch 43/50
# 12/12 [==============================] - 201s 17s/step - loss: 3.4635 - accuracy: 0.3306
# Epoch 44/50
# 12/12 [==============================] - 201s 17s/step - loss: 3.4625 - accuracy: 0.3337
# Epoch 45/50
# 12/12 [==============================] - 201s 17s/step - loss: 3.4616 - accuracy: 0.3330
# Epoch 46/50
# 12/12 [==============================] - 203s 17s/step - loss: 3.4609 - accuracy: 0.3337
# Epoch 47/50
# 12/12 [==============================] - 201s 17s/step - loss: 3.4599 - accuracy: 0.3372
# Epoch 48/50
# 12/12 [==============================] - 201s 17s/step - loss: 3.4596 - accuracy: 0.3394
# Epoch 49/50
# 12/12 [==============================] - 200s 17s/step - loss: 3.4589 - accuracy: 0.3359
# Epoch 50/50
# 12/12 [==============================] - 201s 17s/step - loss: 3.4579 - accuracy: 0.3405

# %%
with tf.device('/CPU:0'):
    history5 = model_other.fit(train_x_resized,train_y_resized,epochs=10
                               ,callbacks=[tensorboard_callback])
# Out:
# Epoch 1/10
# 12/12 [==============================] - 205s 17s/step - loss: 3.4571 - accuracy: 0.3412
# Epoch 2/10
# 12/12 [==============================] - 202s 17s/step - loss: 3.4565 - accuracy: 0.3420
# Epoch 3/10
# 12/12 [==============================] - 202s 17s/step - loss: 3.4552 - accuracy: 0.3447
# Epoch 4/10
# 12/12 [==============================] - 203s 17s/step - loss: 3.4547 - accuracy: 0.3436
# Epoch 5/10
# 12/12 [==============================] - 204s 17s/step - loss: 3.4540 - accuracy: 0.3478
# Epoch 6/10
# 12/12 [==============================] - 205s 17s/step - loss: 3.4532 - accuracy: 0.3455
# Epoch 7/10
# 12/12 [==============================] - 203s 17s/step - loss: 3.4521 - accuracy: 0.3501
# Epoch 8/10
# 12/12 [==============================] - 204s 17s/step - loss: 3.4514 - accuracy: 0.3509
# Epoch 9/10
# 12/12 [==============================] - 203s 17s/step - loss: 3.4506 - accuracy: 0.3527
# Epoch 10/10
# 12/12 [==============================] - 202s 17s/step - loss: 3.4497 - accuracy: 0.3527

# %%
with tf.device('/CPU:0'):
    history6 = model_other.fit(train_x_resized,train_y_resized,epochs=10
                               ,callbacks=[tensorboard_callback])
# Out:
# Epoch 1/10
#  1/12 [=>............................] - ETA: 0s - loss: 3.4464 - accuracy: 0.3666WARNING:tensorflow:From /home/jeremy/.local/lib/python3.6/site-packages/tensorflow/python/ops/summary_ops_v2.py:1271: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# 12/12 [==============================] - 188s 16s/step - loss: 3.4489 - accuracy: 0.3523
# Epoch 2/10
# 12/12 [==============================] - 186s 15s/step - loss: 3.4482 - accuracy: 0.3551
# Epoch 3/10
# 12/12 [==============================] - 187s 16s/step - loss: 3.4475 - accuracy: 0.3562
# Epoch 4/10
# 12/12 [==============================] - 186s 15s/step - loss: 3.4470 - accuracy: 0.3598
# Epoch 5/10
# 12/12 [==============================] - 186s 16s/step - loss: 3.4464 - accuracy: 0.3571
# Epoch 6/10
# 12/12 [==============================] - 186s 15s/step - loss: 3.4456 - accuracy: 0.3599
# Epoch 7/10
# 12/12 [==============================] - 187s 16s/step - loss: 3.4453 - accuracy: 0.3592
# Epoch 8/10
# 12/12 [==============================] - 188s 16s/step - loss: 3.4443 - accuracy: 0.3626
# Epoch 9/10
# 12/12 [==============================] - 187s 16s/step - loss: 3.4434 - accuracy: 0.3597
# Epoch 10/10
# 12/12 [==============================] - 186s 15s/step - loss: 3.4430 - accuracy: 0.3641

# %%
with tf.device('/CPU:0'):
    history7 = model_other.fit(train_x_resized,train_y_resized,epochs=10
                               ,callbacks=[tensorboard_callback])
# Out:
# Epoch 1/10
# 12/12 [==============================] - 187s 16s/step - loss: 3.4422 - accuracy: 0.3620
# Epoch 2/10
# 12/12 [==============================] - 187s 16s/step - loss: 3.4413 - accuracy: 0.3665
# Epoch 3/10
# 12/12 [==============================] - 186s 16s/step - loss: 3.4407 - accuracy: 0.3617
# Epoch 4/10
# 12/12 [==============================] - 186s 16s/step - loss: 3.4400 - accuracy: 0.3643
# Epoch 5/10
# 12/12 [==============================] - 187s 16s/step - loss: 3.4392 - accuracy: 0.3651
# Epoch 6/10
# 12/12 [==============================] - 187s 16s/step - loss: 3.4388 - accuracy: 0.3656
# Epoch 7/10
# 12/12 [==============================] - 199s 17s/step - loss: 3.4380 - accuracy: 0.3666
# Epoch 8/10
# 12/12 [==============================] - 204s 17s/step - loss: 3.4369 - accuracy: 0.3680
# Epoch 9/10
# 12/12 [==============================] - 207s 17s/step - loss: 3.4361 - accuracy: 0.3676
# Epoch 10/10
# 12/12 [==============================] - 219s 18s/step - loss: 3.4353 - accuracy: 0.3700

# %%
with tf.device('/CPU:0'):
    model_other.compile(optimizer=tf.keras.optimizers.Adam(0.001),loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                  metrics=['accuracy'])
    history8 = model_other.fit(train_x_resized,train_y_resized,epochs=10
                               ,callbacks=[tensorboard_callback])
# Out:
# Epoch 1/10
# 12/12 [==============================] - 204s 17s/step - loss: 3.4573 - accuracy: 0.2852
# Epoch 2/10
# 12/12 [==============================] - 188s 16s/step - loss: 3.4357 - accuracy: 0.3187
# Epoch 3/10
# 12/12 [==============================] - 189s 16s/step - loss: 3.4239 - accuracy: 0.3245
# Epoch 4/10
# 12/12 [==============================] - 189s 16s/step - loss: 3.4142 - accuracy: 0.3343
# Epoch 5/10
# 12/12 [==============================] - 190s 16s/step - loss: 3.4052 - accuracy: 0.3347
# Epoch 6/10
# 12/12 [==============================] - 189s 16s/step - loss: 3.3942 - accuracy: 0.3471
# Epoch 7/10
# 12/12 [==============================] - 188s 16s/step - loss: 3.3850 - accuracy: 0.3562
# Epoch 8/10
# 12/12 [==============================] - 189s 16s/step - loss: 3.3735 - accuracy: 0.3607
# Epoch 9/10
# 12/12 [==============================] - 190s 16s/step - loss: 3.3613 - accuracy: 0.3725
# Epoch 10/10
# 12/12 [==============================] - 189s 16s/step - loss: 3.3503 - accuracy: 0.3780

# %%
with tf.device('/CPU:0'):
    history9 = model_other.fit(train_x_resized,train_y_resized,epochs=10
                               ,callbacks=[tensorboard_callback])
# Out:
# Epoch 1/10
# 12/12 [==============================] - 191s 16s/step - loss: 3.3405 - accuracy: 0.3775
# Epoch 2/10
# 12/12 [==============================] - 190s 16s/step - loss: 3.3312 - accuracy: 0.3781
# Epoch 3/10
# 12/12 [==============================] - 190s 16s/step - loss: 3.3248 - accuracy: 0.3769
# Epoch 4/10
# 12/12 [==============================] - 190s 16s/step - loss: 3.3126 - accuracy: 0.3846
# Epoch 5/10
# 12/12 [==============================] - 189s 16s/step - loss: 3.3017 - accuracy: 0.3902
# Epoch 6/10
# 12/12 [==============================] - 190s 16s/step - loss: 3.2932 - accuracy: 0.3918
# Epoch 7/10
# 12/12 [==============================] - 190s 16s/step - loss: 3.2865 - accuracy: 0.3932
# Epoch 8/10
# 12/12 [==============================] - 189s 16s/step - loss: 3.2766 - accuracy: 0.3971
# Epoch 9/10
# 12/12 [==============================] - 190s 16s/step - loss: 3.2726 - accuracy: 0.3957
# Epoch 10/10
# 12/12 [==============================] - 189s 16s/step - loss: 3.2641 - accuracy: 0.3976

# %%
with tf.device('/CPU:0'):
    history10 = model_other.fit(train_x_resized,train_y_resized,epochs=120
                               ,callbacks=[tensorboard_callback])
# Out:
# Epoch 1/120
# 12/12 [==============================] - 223s 19s/step - loss: 3.2584 - accuracy: 0.3979
# Epoch 2/120
# 12/12 [==============================] - 218s 18s/step - loss: 3.2539 - accuracy: 0.4011
# Epoch 3/120
# 12/12 [==============================] - 212s 18s/step - loss: 3.2464 - accuracy: 0.4002
# Epoch 4/120
# 12/12 [==============================] - 217s 18s/step - loss: 3.2427 - accuracy: 0.4012
# Epoch 5/120
# 12/12 [==============================] - 224s 19s/step - loss: 3.2382 - accuracy: 0.4022
# Epoch 6/120
# 12/12 [==============================] - 207s 17s/step - loss: 3.2322 - accuracy: 0.4032
# Epoch 7/120
# 12/12 [==============================] - 213s 18s/step - loss: 3.2284 - accuracy: 0.4049
# Epoch 8/120
# 12/12 [==============================] - 220s 18s/step - loss: 3.2247 - accuracy: 0.4055
# Epoch 9/120
# 12/12 [==============================] - 216s 18s/step - loss: 3.2210 - accuracy: 0.4059
# Epoch 10/120
# 12/12 [==============================] - 219s 18s/step - loss: 3.2165 - accuracy: 0.4083
# Epoch 11/120
# 12/12 [==============================] - 197s 16s/step - loss: 3.2125 - accuracy: 0.4102
# Epoch 12/120
# 12/12 [==============================] - 194s 16s/step - loss: 3.2071 - accuracy: 0.4129
# Epoch 13/120
# 12/12 [==============================] - 193s 16s/step - loss: 3.2022 - accuracy: 0.4193
# Epoch 14/120
# 12/12 [==============================] - 195s 16s/step - loss: 3.1937 - accuracy: 0.4309
# Epoch 15/120
# 12/12 [==============================] - 195s 16s/step - loss: 3.1855 - accuracy: 0.4392
# Epoch 16/120
# 12/12 [==============================] - 194s 16s/step - loss: 3.1780 - accuracy: 0.4318
# Epoch 17/120
# 12/12 [==============================] - 194s 16s/step - loss: 3.1703 - accuracy: 0.4435
# Epoch 18/120
# 12/12 [==============================] - 195s 16s/step - loss: 3.1654 - accuracy: 0.4335
# Epoch 19/120
# 12/12 [==============================] - 195s 16s/step - loss: 3.1598 - accuracy: 0.4484
# Epoch 20/120
# 12/12 [==============================] - 194s 16s/step - loss: 3.1541 - accuracy: 0.4534
# Epoch 21/120
# 12/12 [==============================] - 195s 16s/step - loss: 3.1503 - accuracy: 0.4674
# Epoch 22/120
# 12/12 [==============================] - 195s 16s/step - loss: 3.1469 - accuracy: 0.4858
# Epoch 23/120
# 12/12 [==============================] - 195s 16s/step - loss: 3.1407 - accuracy: 0.4875
# Epoch 24/120
# 12/12 [==============================] - 194s 16s/step - loss: 3.1362 - accuracy: 0.5336
# Epoch 25/120
# 12/12 [==============================] - 195s 16s/step - loss: 3.1320 - accuracy: 0.5779
# Epoch 26/120
# 12/12 [==============================] - 194s 16s/step - loss: 3.1283 - accuracy: 0.6127
# Epoch 27/120
# 12/12 [==============================] - 196s 16s/step - loss: 3.1248 - accuracy: 0.6325
# Epoch 28/120
# 12/12 [==============================] - 197s 16s/step - loss: 3.1170 - accuracy: 0.6710
# Epoch 29/120
# 12/12 [==============================] - 194s 16s/step - loss: 3.1108 - accuracy: 0.6918
# Epoch 30/120
# 12/12 [==============================] - 195s 16s/step - loss: 3.1039 - accuracy: 0.6949
# Epoch 31/120
# 12/12 [==============================] - 195s 16s/step - loss: 3.0958 - accuracy: 0.6975
# Epoch 32/120
# 12/12 [==============================] - 195s 16s/step - loss: 3.0845 - accuracy: 0.6996
# Epoch 33/120
# 12/12 [==============================] - 195s 16s/step - loss: 3.0714 - accuracy: 0.7015
# Epoch 34/120
# 12/12 [==============================] - 194s 16s/step - loss: 3.0579 - accuracy: 0.7014
# Epoch 35/120
# 12/12 [==============================] - 194s 16s/step - loss: 3.0436 - accuracy: 0.7015
# Epoch 36/120
# 12/12 [==============================] - 193s 16s/step - loss: 3.0298 - accuracy: 0.7006
# Epoch 37/120
# 12/12 [==============================] - 194s 16s/step - loss: 3.0181 - accuracy: 0.6966
# Epoch 38/120
# 12/12 [==============================] - 193s 16s/step - loss: 3.0070 - accuracy: 0.6930
# Epoch 39/120
# 12/12 [==============================] - 194s 16s/step - loss: 2.9919 - accuracy: 0.6851
# Epoch 40/120
# 12/12 [==============================] - 196s 16s/step - loss: 2.9820 - accuracy: 0.6763
# Epoch 41/120
# 12/12 [==============================] - 193s 16s/step - loss: 2.9708 - accuracy: 0.6761
# Epoch 42/120
# 12/12 [==============================] - 193s 16s/step - loss: 2.9591 - accuracy: 0.6759
# Epoch 43/120
# 12/12 [==============================] - 194s 16s/step - loss: 2.9501 - accuracy: 0.6774
# Epoch 44/120
# 12/12 [==============================] - 194s 16s/step - loss: 2.9416 - accuracy: 0.6789
# Epoch 45/120
# 12/12 [==============================] - 194s 16s/step - loss: 2.9345 - accuracy: 0.6799
# Epoch 46/120
# 12/12 [==============================] - 196s 16s/step - loss: 2.9282 - accuracy: 0.6806
# Epoch 47/120
# 12/12 [==============================] - 195s 16s/step - loss: 2.9242 - accuracy: 0.6812
# Epoch 48/120
# 12/12 [==============================] - 194s 16s/step - loss: 2.9195 - accuracy: 0.6818
# Epoch 49/120
# 12/12 [==============================] - 194s 16s/step - loss: 2.9174 - accuracy: 0.6821
# Epoch 50/120
# 12/12 [==============================] - 195s 16s/step - loss: 2.9149 - accuracy: 0.6824
# Epoch 51/120
# 12/12 [==============================] - 195s 16s/step - loss: 2.9129 - accuracy: 0.6826
# Epoch 52/120
# 12/12 [==============================] - 193s 16s/step - loss: 2.9094 - accuracy: 0.6829
# Epoch 53/120
# 12/12 [==============================] - 197s 16s/step - loss: 2.9058 - accuracy: 0.6830
# Epoch 54/120
# 12/12 [==============================] - 195s 16s/step - loss: 2.9059 - accuracy: 0.6833
# Epoch 55/120
# 12/12 [==============================] - 193s 16s/step - loss: 2.9051 - accuracy: 0.6834
# Epoch 56/120
# 12/12 [==============================] - 193s 16s/step - loss: 2.9034 - accuracy: 0.6835
# Epoch 57/120
# 12/12 [==============================] - 194s 16s/step - loss: 2.9015 - accuracy: 0.6836
# Epoch 58/120
# 12/12 [==============================] - 195s 16s/step - loss: 2.9013 - accuracy: 0.6837
# Epoch 59/120
# 12/12 [==============================] - 194s 16s/step - loss: 2.8988 - accuracy: 0.6838
# Epoch 60/120
# 12/12 [==============================] - 194s 16s/step - loss: 2.8994 - accuracy: 0.6838
# Epoch 61/120
# 12/12 [==============================] - 195s 16s/step - loss: 2.8991 - accuracy: 0.6839
# Epoch 62/120
# 12/12 [==============================] - 194s 16s/step - loss: 2.8967 - accuracy: 0.6840
# Epoch 63/120
# 12/12 [==============================] - 195s 16s/step - loss: 2.8960 - accuracy: 0.6841
# Epoch 64/120
# 12/12 [==============================] - 194s 16s/step - loss: 2.8940 - accuracy: 0.6841
# Epoch 65/120
# 12/12 [==============================] - 193s 16s/step - loss: 2.8954 - accuracy: 0.6840
# Epoch 66/120
# 12/12 [==============================] - 195s 16s/step - loss: 2.8948 - accuracy: 0.6841
# Epoch 67/120
# 12/12 [==============================] - 198s 16s/step - loss: 2.8934 - accuracy: 0.6843
# Epoch 68/120
# 12/12 [==============================] - 196s 16s/step - loss: 2.8929 - accuracy: 0.6843
# Epoch 69/120
# 12/12 [==============================] - 194s 16s/step - loss: 2.8900 - accuracy: 0.6844
# Epoch 70/120
# 12/12 [==============================] - 195s 16s/step - loss: 2.8906 - accuracy: 0.6845
# Epoch 71/120
# 12/12 [==============================] - 193s 16s/step - loss: 2.8913 - accuracy: 0.6845
# Epoch 72/120
# 12/12 [==============================] - 194s 16s/step - loss: 2.8948 - accuracy: 0.6845
# Epoch 73/120
# 12/12 [==============================] - 194s 16s/step - loss: 2.8890 - accuracy: 0.6845
# Epoch 74/120
# 12/12 [==============================] - 193s 16s/step - loss: 2.8900 - accuracy: 0.6845
# Epoch 75/120
# 12/12 [==============================] - 194s 16s/step - loss: 2.8891 - accuracy: 0.6846
# Epoch 76/120
# 12/12 [==============================] - 193s 16s/step - loss: 2.8875 - accuracy: 0.6847
# Epoch 77/120
# 12/12 [==============================] - 194s 16s/step - loss: 2.8871 - accuracy: 0.6847
# Epoch 78/120
# 12/12 [==============================] - 194s 16s/step - loss: 2.8871 - accuracy: 0.6847
# Epoch 79/120
# 12/12 [==============================] - 194s 16s/step - loss: 2.8878 - accuracy: 0.6848
# Epoch 80/120
# 12/12 [==============================] - 194s 16s/step - loss: 2.8866 - accuracy: 0.6848
# Epoch 81/120
# 12/12 [==============================] - 195s 16s/step - loss: 2.8852 - accuracy: 0.6849
# Epoch 82/120
# 12/12 [==============================] - 194s 16s/step - loss: 2.8850 - accuracy: 0.6848
# Epoch 83/120
# 12/12 [==============================] - 194s 16s/step - loss: 2.8855 - accuracy: 0.6849
# Epoch 84/120
# 12/12 [==============================] - 194s 16s/step - loss: 2.8861 - accuracy: 0.6849
# Epoch 85/120
# 12/12 [==============================] - 194s 16s/step - loss: 2.8845 - accuracy: 0.6849
# Epoch 86/120
# 12/12 [==============================] - 194s 16s/step - loss: 2.8856 - accuracy: 0.6850
# Epoch 87/120
# 12/12 [==============================] - 195s 16s/step - loss: 2.8841 - accuracy: 0.6850
# Epoch 88/120
# 12/12 [==============================] - 194s 16s/step - loss: 2.8836 - accuracy: 0.6851
# Epoch 89/120
# 12/12 [==============================] - 194s 16s/step - loss: 2.8820 - accuracy: 0.6853
# Epoch 90/120
# 12/12 [==============================] - 194s 16s/step - loss: 2.8823 - accuracy: 0.6855
# Epoch 91/120
# 12/12 [==============================] - 194s 16s/step - loss: 2.8812 - accuracy: 0.6856
# Epoch 92/120
# 12/12 [==============================] - 194s 16s/step - loss: 2.8805 - accuracy: 0.6863
# Epoch 93/120
# 12/12 [==============================] - 194s 16s/step - loss: 2.8803 - accuracy: 0.6863
# Epoch 94/120
# 12/12 [==============================] - 195s 16s/step - loss: 2.8794 - accuracy: 0.6870
# Epoch 95/120
# 12/12 [==============================] - 196s 16s/step - loss: 2.8821 - accuracy: 0.6876
# Epoch 96/120
# 12/12 [==============================] - 194s 16s/step - loss: 2.8765 - accuracy: 0.6883
# Epoch 97/120
# 12/12 [==============================] - 194s 16s/step - loss: 2.8769 - accuracy: 0.6928
# Epoch 98/120
# 12/12 [==============================] - 195s 16s/step - loss: 2.8757 - accuracy: 0.6962
# Epoch 99/120
# 12/12 [==============================] - 193s 16s/step - loss: 2.8749 - accuracy: 0.7132
# Epoch 100/120
# 12/12 [==============================] - 196s 16s/step - loss: 2.8729 - accuracy: 0.7218
# Epoch 101/120
# 12/12 [==============================] - 193s 16s/step - loss: 2.8688 - accuracy: 0.7348
# Epoch 102/120
# 12/12 [==============================] - 194s 16s/step - loss: 2.8686 - accuracy: 0.7412
# Epoch 103/120
# 12/12 [==============================] - 194s 16s/step - loss: 2.8657 - accuracy: 0.7452
# Epoch 104/120
# 12/12 [==============================] - 196s 16s/step - loss: 2.8625 - accuracy: 0.7462
# Epoch 105/120
# 12/12 [==============================] - 194s 16s/step - loss: 2.8588 - accuracy: 0.7469
# Epoch 106/120
# 12/12 [==============================] - 193s 16s/step - loss: 2.8557 - accuracy: 0.7472
# Epoch 107/120
# 12/12 [==============================] - 194s 16s/step - loss: 2.8543 - accuracy: 0.7475
# Epoch 108/120
# 12/12 [==============================] - 194s 16s/step - loss: 2.8524 - accuracy: 0.7472
# Epoch 109/120
# 12/12 [==============================] - 194s 16s/step - loss: 2.8655 - accuracy: 0.7362
# Epoch 110/120
# 12/12 [==============================] - 195s 16s/step - loss: 2.8916 - accuracy: 0.7076
# Epoch 111/120
# 12/12 [==============================] - 195s 16s/step - loss: 2.8869 - accuracy: 0.7122
# Epoch 112/120
# 12/12 [==============================] - 194s 16s/step - loss: 2.8785 - accuracy: 0.7210
# Epoch 113/120
# 12/12 [==============================] - 193s 16s/step - loss: 2.8719 - accuracy: 0.7268
# Epoch 114/120
# 12/12 [==============================] - 194s 16s/step - loss: 2.8666 - accuracy: 0.7279
# Epoch 115/120
# 12/12 [==============================] - 194s 16s/step - loss: 2.8601 - accuracy: 0.7338
# Epoch 116/120
# 12/12 [==============================] - 195s 16s/step - loss: 2.8591 - accuracy: 0.7369
# Epoch 117/120
# 12/12 [==============================] - 194s 16s/step - loss: 2.8548 - accuracy: 0.7398
# Epoch 118/120
# 12/12 [==============================] - 197s 16s/step - loss: 2.8494 - accuracy: 0.7417
# Epoch 119/120
# 12/12 [==============================] - 195s 16s/step - loss: 2.8478 - accuracy: 0.7429
# Epoch 120/120
# 12/12 [==============================] - 194s 16s/step - loss: 2.8455 - accuracy: 0.7440

# %%
with tf.device('/CPU:0'):
    history12 = model_other.fit(train_x_resized,train_y_resized,epochs=120
                               ,callbacks=[tensorboard_callback])
# Out:
# Epoch 1/120
#  1/12 [=>............................] - ETA: 0s - loss: 2.8401 - accuracy: 0.7483WARNING:tensorflow:From /home/jeremy/.local/lib/python3.6/site-packages/tensorflow/python/ops/summary_ops_v2.py:1271: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# 12/12 [==============================] - 191s 16s/step - loss: 2.8478 - accuracy: 0.7414
# Epoch 2/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.8436 - accuracy: 0.7439
# Epoch 3/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.8399 - accuracy: 0.7453
# Epoch 4/120
# 12/12 [==============================] - 189s 16s/step - loss: 2.8410 - accuracy: 0.7459
# Epoch 5/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.8389 - accuracy: 0.7466
# Epoch 6/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.8340 - accuracy: 0.7472
# Epoch 7/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.8337 - accuracy: 0.7476
# Epoch 8/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.8348 - accuracy: 0.7477
# Epoch 9/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.8344 - accuracy: 0.7479
# Epoch 10/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.8317 - accuracy: 0.7480
# Epoch 11/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.8318 - accuracy: 0.7481
# Epoch 12/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.8288 - accuracy: 0.7484
# Epoch 13/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.8307 - accuracy: 0.7484
# Epoch 14/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.8288 - accuracy: 0.7487
# Epoch 15/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.8279 - accuracy: 0.7488
# Epoch 16/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.8272 - accuracy: 0.7490
# Epoch 17/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.8272 - accuracy: 0.7491
# Epoch 18/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.8231 - accuracy: 0.7493
# Epoch 19/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.8250 - accuracy: 0.7493
# Epoch 20/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.8263 - accuracy: 0.7493
# Epoch 21/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.8243 - accuracy: 0.7493
# Epoch 22/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.8245 - accuracy: 0.7492
# Epoch 23/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.8259 - accuracy: 0.7493
# Epoch 24/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.8230 - accuracy: 0.7494
# Epoch 25/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.8245 - accuracy: 0.7496
# Epoch 26/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.8217 - accuracy: 0.7496
# Epoch 27/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.8211 - accuracy: 0.7498
# Epoch 28/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.8215 - accuracy: 0.7498
# Epoch 29/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.8240 - accuracy: 0.7499
# Epoch 30/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.8202 - accuracy: 0.7499
# Epoch 31/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.8212 - accuracy: 0.7499
# Epoch 32/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.8213 - accuracy: 0.7500
# Epoch 33/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.8201 - accuracy: 0.7501
# Epoch 34/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.8236 - accuracy: 0.7501
# Epoch 35/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.8198 - accuracy: 0.7501
# Epoch 36/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.8182 - accuracy: 0.7502
# Epoch 37/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.8180 - accuracy: 0.7502
# Epoch 38/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.8190 - accuracy: 0.7500
# Epoch 39/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.8181 - accuracy: 0.7501
# Epoch 40/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.8174 - accuracy: 0.7500
# Epoch 41/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.8181 - accuracy: 0.7497
# Epoch 42/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.8166 - accuracy: 0.7496
# Epoch 43/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.8175 - accuracy: 0.7498
# Epoch 44/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.8195 - accuracy: 0.7498
# Epoch 45/120
# 12/12 [==============================] - 189s 16s/step - loss: 2.8127 - accuracy: 0.7509
# Epoch 46/120
# 12/12 [==============================] - 189s 16s/step - loss: 2.8135 - accuracy: 0.7529
# Epoch 47/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.8142 - accuracy: 0.7623
# Epoch 48/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.8132 - accuracy: 0.7710
# Epoch 49/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.8114 - accuracy: 0.7762
# Epoch 50/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.8101 - accuracy: 0.7848
# Epoch 51/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.8090 - accuracy: 0.7893
# Epoch 52/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.8074 - accuracy: 0.7919
# Epoch 53/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.8069 - accuracy: 0.7928
# Epoch 54/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.8071 - accuracy: 0.7931
# Epoch 55/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.8038 - accuracy: 0.7946
# Epoch 56/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.8052 - accuracy: 0.7951
# Epoch 57/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.8015 - accuracy: 0.7956
# Epoch 58/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.8017 - accuracy: 0.7959
# Epoch 59/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.8013 - accuracy: 0.7964
# Epoch 60/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.7996 - accuracy: 0.7966
# Epoch 61/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.7984 - accuracy: 0.7967
# Epoch 62/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.7971 - accuracy: 0.7968
# Epoch 63/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.7952 - accuracy: 0.7968
# Epoch 64/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.7940 - accuracy: 0.7968
# Epoch 65/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.7918 - accuracy: 0.7969
# Epoch 66/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.7900 - accuracy: 0.7970
# Epoch 67/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.7892 - accuracy: 0.7973
# Epoch 68/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.7870 - accuracy: 0.7975
# Epoch 69/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.7854 - accuracy: 0.7975
# Epoch 70/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.7829 - accuracy: 0.7977
# Epoch 71/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.7845 - accuracy: 0.7977
# Epoch 72/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.7825 - accuracy: 0.7976
# Epoch 73/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.7814 - accuracy: 0.7976
# Epoch 74/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.7828 - accuracy: 0.7978
# Epoch 75/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.7810 - accuracy: 0.7979
# Epoch 76/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.7786 - accuracy: 0.7980
# Epoch 77/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.7786 - accuracy: 0.7981
# Epoch 78/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.7775 - accuracy: 0.7982
# Epoch 79/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.7780 - accuracy: 0.7981
# Epoch 80/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.7781 - accuracy: 0.7982
# Epoch 81/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.7750 - accuracy: 0.7982
# Epoch 82/120
# 12/12 [==============================] - 189s 16s/step - loss: 2.7769 - accuracy: 0.7983
# Epoch 83/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.7747 - accuracy: 0.7982
# Epoch 84/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.7743 - accuracy: 0.7983
# Epoch 85/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.7740 - accuracy: 0.7981
# Epoch 86/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.7727 - accuracy: 0.7982
# Epoch 87/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.7714 - accuracy: 0.8010
# Epoch 88/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.7723 - accuracy: 0.8098
# Epoch 89/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.7703 - accuracy: 0.8197
# Epoch 90/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.7698 - accuracy: 0.8227
# Epoch 91/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.7706 - accuracy: 0.8252
# Epoch 92/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.7689 - accuracy: 0.8282
# Epoch 93/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.7706 - accuracy: 0.8284
# Epoch 94/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.7691 - accuracy: 0.8286
# Epoch 95/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.7661 - accuracy: 0.8292
# Epoch 96/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.7659 - accuracy: 0.8291
# Epoch 97/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.7668 - accuracy: 0.8296
# Epoch 98/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.7650 - accuracy: 0.8297
# Epoch 99/120
# 12/12 [==============================] - 189s 16s/step - loss: 2.7645 - accuracy: 0.8299
# Epoch 100/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.7645 - accuracy: 0.8300
# Epoch 101/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.7632 - accuracy: 0.8300
# Epoch 102/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.7639 - accuracy: 0.8299
# Epoch 103/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.7616 - accuracy: 0.8300
# Epoch 104/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.7615 - accuracy: 0.8301
# Epoch 105/120
# 12/12 [==============================] - 190s 16s/step - loss: 2.7597 - accuracy: 0.8302
# Epoch 106/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.7598 - accuracy: 0.8303
# Epoch 107/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.7602 - accuracy: 0.8303
# Epoch 108/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.7590 - accuracy: 0.8301
# Epoch 109/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.7613 - accuracy: 0.8302
# Epoch 110/120
# 12/12 [==============================] - 189s 16s/step - loss: 2.7584 - accuracy: 0.8301
# Epoch 111/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.7563 - accuracy: 0.8300
# Epoch 112/120
# 12/12 [==============================] - 189s 16s/step - loss: 2.7564 - accuracy: 0.8300
# Epoch 113/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.7568 - accuracy: 0.8301
# Epoch 114/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.7551 - accuracy: 0.8302
# Epoch 115/120
# 12/12 [==============================] - 189s 16s/step - loss: 2.7540 - accuracy: 0.8304
# Epoch 116/120
# 12/12 [==============================] - 189s 16s/step - loss: 2.7557 - accuracy: 0.8303
# Epoch 117/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.7529 - accuracy: 0.8305
# Epoch 118/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.7534 - accuracy: 0.8319
# Epoch 119/120
# 12/12 [==============================] - 187s 16s/step - loss: 2.7512 - accuracy: 0.8321
# Epoch 120/120
# 12/12 [==============================] - 188s 16s/step - loss: 2.7494 - accuracy: 0.8328

# %%
#Tensorboard shows the various training stages.
# %tensorboard --logdir logs/fit
# Out:
# Reusing TensorBoard on port 6006 (pid 15774), started 0:34:27 ago. (Use '!kill 15774' to kill it.)
#       <iframe id="tensorboard-frame-4554e9e8f6d383b9" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-4554e9e8f6d383b9");
#           const url = new URL("/", window.location);
#           url.port = 6006;
#           frame.src = url;
#         })();
#       </script>

# %%
#Show predicated class for an image
#Class is chosen as the most likely class for each pixel
predictions = model_other.predict(train_x_resized[0:5])
flat_pred = (predictions.flatten())
predictions.shape
plt.imshow(np.array(tf.argmax(predictions[1,:,:,:],axis=-1)), interpolation='nearest')
np.shape(tf.argmax(predictions[:,:,:,:],axis=-1))
# Out:
# TensorShape([5, 224, 224])

# %%
#Ground truth
plt.imshow(train_y_resized[1,:,:,0], interpolation='nearest')

# %%
#Test 
loss, acc = model_other.evaluate(test_x_resized,  test_y_resized, verbose=2)
acc
# Out:
# 3/3 - 2s
# 0.6578083038330078

# %%
#Model saving
#Useful to checkpoint work.
model_other.save('saved_model/VGGwithPassthroughImageNetPreTrainedV6_10xV5toV6_120epochs')

# %%
#Loading model.
model_other = tf.keras.models.load_model('saved_model/VGGwithPassthroughImageNetPreTrainedV6_10xV5toV6_120epochs')

# %% [markdown]
# Results:
# The current in-sample accuracy was 0.8328, whereas out of sample accuracy is 0.6578. The model still shows steady progress when trained for longer. At initial training, the accuracy on in-sample examples below 0.0184, so there's a definite improvement.
#
# Qualitatively, the model is doing what it is supposed to. By eye, the hand-annotated images in the training set is close to the generate map of labels from the model.

# %% [markdown]
# Conclusions
#
# I have a created a roughly working image segmentation neural network that is identify a range of objects in an urban environment. By presenting this information in a single documented notebook, I hope it is instructive in building image segmentation networks for Tensorflow 2.x using Keras. The model was trained over a few dozen hours on a Intel® Core™ i5-4670 CPU.
#
# Areas for improvement:
# Computational:
# Increasing the number of training epochs would increase the accuracy. The model is showing steady improvement with successive iterations, so likely it will continue to improve in training accuracy. There is a significant difference in accuracy between the train and test examples. The neural net was run over only 32 images to speed training, so running over a higher number of samples from the Cityscapes data set would improve it.
# Algorithmic:
# There are a number of hyperparameters to optimized, as well as the network topography. The learning rate is a key one hyperparameter. I experimented in increasing it by 10x to 0.001 from 0.0001, and that did improve the speed of training. However, an additional 10x does not improve performance. In addition, the order of layers can be adjusted. Different numbers of convultion filter, changing the depth of the network, and using different layers for passthrough would change the performance of the network. The decoder network is less deep than the VGG encoder network and has a somewhat different shape. Much of the established literature has symmetric encoder and decoder networks, so this topography is more experimental.
# Structural:
# There are a number of improvements that can be done with the code. Tensorflow training checkpoints could be used to more robustly create versioning for experiments. By rescaling the images to 224x224, some data is lost from the training set. The model can be trained with a validation training set in order to see the change of in-sample and out-of-sample error rates. The data could be loaded in more elegantly.

# %%
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function BatchNormalizationBase.call at 0x7fc4652a8840> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please  define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function BatchNormalizationBase.call at 0x7fc4652a8840> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please  define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:7 out of the last 7 calls to <function BatchNormalizationBase.call at 0x7fc4651bd6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please  define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:8 out of the last 8 calls to <function BatchNormalizationBase.call at 0x7fc4651bd6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please  define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:9 out of the last 9 calls to <function BatchNormalizationBase.call at 0x7fc465154510> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please  define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:10 out of the last 10 calls to <function BatchNormalizationBase.call at 0x7fc465154510> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please  define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# INFO:tensorflow:Assets written to: saved_model/VGGwithPassthroughImageNetPreTrainedV6_10xV5toV6_120epochs/assets
